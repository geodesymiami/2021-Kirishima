# %% [markdown]
# ## Load GBIS inversion result into HDF5 format

# %%
import os
from mintpy import load_gbis

model_dir = os.path.expanduser('~/insarlab/Kirishima/Model')
os.chdir(model_dir)
print('Go to directory', model_dir)

load_gbis.main(['Shinmoe2008post/invert_1_2_C/invert_1_2_C.mat'])
load_gbis.main(['Shinmoe2017pre/invert_1_2_T/invert_1_2_T.mat'])
load_gbis.main(['Iwo/invert_1_2_C/invert_1_2_C.mat'])
# Out:
# Go to directory /Users/yunjunz/insarlab/Kirishima/Model
# read mat file: /Users/yunjunz/insarlab/Kirishima/Model/Shinmoe2008post/invert_1_2_C/invert_1_2_C.mat
# number of output HDF5 file: 2
# creating figure in size of [12, 6]
# ------------------------------
# read mask from file: /Users/yunjunz/insarlab/Kirishima/Model/data/KirishimaAlosAT424_20080929_20100705.mat
# delete exsited file: /Users/yunjunz/insarlab/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosAT424_20080929_20100705.h5
# create HDF5 file: /Users/yunjunz/insarlab/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosAT424_20080929_20100705.h5 with w mode
# create dataset /data     of float32    in size of (361, 361)           with compression=None
# create dataset /model    of float32    in size of (361, 361)           with compression=None
# create dataset /residual of float32    in size of (361, 361)           with compression=None
# ...
