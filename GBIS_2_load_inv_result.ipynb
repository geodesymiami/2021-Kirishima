# %% [markdown]
# ## Load GBIS inversion result into HDF5 format

# %%
import os
from mintpy import load_gbis

model_dir = os.path.expanduser('~/data/Kirishima/Model')
os.chdir(model_dir)
print('Go to directory', model_dir)

load_gbis.main(['Shinmoe2008post/invert_1_2_C/invert_1_2_C.mat'])
load_gbis.main(['Shinmoe2017pre/invert_1_2_C/invert_1_2_C.mat'])
load_gbis.main(['Iwo2017pre/invert_1_2_C/invert_1_2_C.mat'])
load_gbis.main(['Iwo2017post/invert_1_2_C_C2/invert_1_2_C_C2.mat'])
# Out:
# Go to directory /Users/yunjunz/data/Kirishima/Model
# read mat file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/invert_1_2_C.mat
# number of output HDF5 file: 2
# creating figure in size of [12, 6]
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlosAT424_20080929_20100705.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosAT424_20080929_20100705.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosAT424_20080929_20100705.h5 with w mode
# create dataset /data     of float32    in size of (361, 361)           with compression=None
# create dataset /model    of float32    in size of (361, 361)           with compression=None
# create dataset /residual of float32    in size of (361, 361)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosAT424_20080929_20100705.h5
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlosDT73_20081012_20100302.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosDT73_20081012_20100302.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosDT73_20081012_20100302.h5 with w mode
# create dataset /data     of float32    in size of (361, 361)           with compression=None
# create dataset /model    of float32    in size of (361, 361)           with compression=None
# create dataset /residual of float32    in size of (361, 361)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Shinmoe2008post/invert_1_2_C/KirishimaAlosDT73_20081012_20100302.h5
# showing ...
# read mat file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/invert_1_2_C.mat
# number of output HDF5 file: 2
# creating figure in size of [12, 6]
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2AT131_20150106_20171010.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2DT23_20150209_20170918.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Shinmoe2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5
# showing ...
# read mat file: /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/invert_1_2_C.mat
# number of output HDF5 file: 2
# creating figure in size of [12, 6]
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2AT131_20150106_20171010.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2AT131_20150106_20171010.h5
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2DT23_20150209_20170918.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Iwo2017pre/invert_1_2_C/KirishimaAlos2DT23_20150209_20170918.h5
# showing ...
# read mat file: /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/invert_1_2_C_C2.mat
# number of output HDF5 file: 2
# creating figure in size of [12, 6]
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2AT131_20171219_20190702.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2AT131_20171219_20190702.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2AT131_20171219_20190702.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2AT131_20171219_20190702.h5
# ------------------------------
# read mask from file: /Users/yunjunz/data/Kirishima/Model/data/KirishimaAlos2DT23_20171211_20190819.mat
# delete exsited file: /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2DT23_20171211_20190819.h5
# create HDF5 file: /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2DT23_20171211_20190819.h5 with w mode
# create dataset /data     of float32    in size of (541, 541)           with compression=None
# create dataset /model    of float32    in size of (541, 541)           with compression=None
# create dataset /residual of float32    in size of (541, 541)           with compression=None
# finished writing to /Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2DT23_20171211_20190819.h5
# showing ...
# ['/Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2AT131_20171219_20190702.h5',
#  '/Users/yunjunz/data/Kirishima/Model/Iwo2017post/invert_1_2_C_C2/KirishimaAlos2DT23_20171211_20190819.h5']
